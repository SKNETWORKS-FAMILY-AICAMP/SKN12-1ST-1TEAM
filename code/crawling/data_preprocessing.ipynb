# %% [markdown]
# ## 엑셀파일 외래키 추가

# %%
import pandas as pd

# CSV 파일 읽기
car_sales_df = pd.read_csv('C:/Users/82105/Downloads/car_sales_final.csv', encoding = 'cp949')

# 데이터 확인
print(car_sales_df.head())  # 데이터 상위 5개 행 출력
# Out:
#    id brand_temp model  sales  month
# 0   1         현대   싼타페   8014      1
# 1   2         현대    투싼   5152      1
# 2   3         현대   포터2   4923      1
# 3   4         현대   아반떼   4392      1
# 4   5         현대   그랜저   3635      1

# %%
car_sales_df = car_sales_df.drop('id', axis = 1)

# %%
car_sales_df
# Out:
#              brand_temp model  sales  month
# 0                    현대   싼타페   8014      1
# 1                    현대    투싼   5152      1
# 2                    현대   포터2   4923      1
# 3                    현대   아반떼   4392      1
# 4                    현대   그랜저   3635      1
# ...                 ...   ...    ...    ...
# 1185                S60    볼보   1239      0
# 1186  V60 Cross Country    볼보    934      0
# 1187  V90 Cross Country    볼보    269      0
# 1188       C40 Recharge    볼보    218      0
# 1189      XC40 Recharge    볼보    107      0
#
# [1190 rows x 4 columns]

# %%
import mysql.connector as connector
def get_model_id(model_name):
# 데이터 베이스 연결 정보
    args = {
        'host':'localhost', 
        'user':'root', 
        'password': 'Rladnjsdn9911!', 
        'port': 3306,
    }
    print('접속 완료')
    # 접속 여부 확인
    try:
        conn = connector.connect(**args)
        cursor = conn.cursor()
    
        query = f'''
            select model_id from car_projects.model where model_name = '{model_name}'
        '''
        
        cursor.execute(query)

        return cursor.fetchall()[0][0]
    except Exception as e:
        print(f'error: {e}')
        return False
    else:
        print('정상 처리 되었습니다.')
    finally:
        # 사용이 종료되었을 경우
        if cursor: cursor.close()
        if conn: conn.close()

# %%
model_name_list = list(car_sales_df['model'])
model_id = [ get_model_id(model_name) for model_name in model_name_list]
# Out:
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# 접속 완료
# ...

# %%
car_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales           1190 non-null   int64
#  1   month           1190 non-null   int64
#  2   sales_model_id  1190 non-null   object
# dtypes: int64(2), object(1)
# memory usage: 28.0+ KB
